# %%
import FinanceDataReader as fdr
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings
import matplotlib as mpl
warnings.filterwarnings('ignore')
mpl.rc('font', family='Malgun Gothic')  
mpl.rcParams['axes.unicode_minus'] = False

start_date = '2007-10-04' #경선확정일 - 10
end_date = '2007-10-24' #경선확정일 + 10

thema1 = fdr.DataReader('017800', start=start_date, end=end_date) #테마주1
thema2 = fdr.DataReader('005110', start=start_date, end=end_date)
thema3 = fdr.DataReader('049630', start=start_date, end=end_date)
thema4 = fdr.DataReader('089230', start=start_date, end=end_date)
thema5 = fdr.DataReader('011200', start=start_date, end=end_date)
thema6 = fdr.DataReader('025980', start=start_date, end=end_date)
thema7 = fdr.DataReader('009270', start=start_date, end=end_date)
#테마주2  테마를 추가하고싶으면 아래에 이어서 적으시면됩니다.# thema2 = fdr.DataReader('015260', start=start_date, end=end_date) 
#(1) 이 밑으로 계속 추가한 후 plt 부분에 같이 추가하시면 같이 시각화 가능

thema= pd.DataFrame()

thema['thema1'] = thema1['Close']
thema['thema2'] = thema2['Close']
thema['thema3'] = thema3['Close']
thema['thema4'] = thema4['Close']
thema['thema5'] = thema5['Close']
thema['thema6'] = thema5['Close']
thema['thema7'] = thema5['Close']
#(1)에 추가했을 경우 이 부분도 추가해주세요


plt.figure(figsize=(12, 6))
plt.plot(thema.index, thema['thema1'], label='현대엘리베이터')
plt.plot(thema.index, thema['thema2'], label='한창')
plt.plot(thema.index, thema['thema3'], label='재영솔루텍')
plt.plot(thema.index, thema['thema4'], label='용현BM')
plt.plot(thema.index, thema['thema5'], label='현대상선')
plt.plot(thema.index, thema['thema6'], label='에머슨퍼시픽')
plt.plot(thema.index, thema['thema7'], label='신원')
#(1)에 추가했을 경우 이 부분도 추가해주세요

#경선 일에 빨간 점선 줄
plt.axvline(x=pd.to_datetime('2007-10-14'), color='red', linestyle='--', label='경선일') #경선일을 수정하려면 datatime변수 수정해주시면 됩니다.

plt.xlabel('날짜')
plt.ylabel('종가')
plt.title('정동영_테마주')
plt.legend()
plt.grid(True)
plt.show()

# %%
import FinanceDataReader as fdr
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings
import matplotlib as mpl
warnings.filterwarnings('ignore')
mpl.rc('font', family='Malgun Gothic')  
mpl.rcParams['axes.unicode_minus'] = False

start_date = '2007-11-09' #경선확정일 - 40
end_date = '2007-01-28' #경선확정일 + 40

thema1 = fdr.DataReader('017800', start=start_date, end=end_date) #테마주1
thema2 = fdr.DataReader('005110', start=start_date, end=end_date)
thema3 = fdr.DataReader('049630', start=start_date, end=end_date)
thema4 = fdr.DataReader('089230', start=start_date, end=end_date)
thema5 = fdr.DataReader('011200', start=start_date, end=end_date)
thema6 = fdr.DataReader('025980', start=start_date, end=end_date)
thema7 = fdr.DataReader('009270', start=start_date, end=end_date)
#테마주2  테마를 추가하고싶으면 아래에 이어서 적으시면됩니다.# thema2 = fdr.DataReader('015260', start=start_date, end=end_date) 
#(1) 이 밑으로 계속 추가한 후 plt 부분에 같이 추가하시면 같이 시각화 가능

thema= pd.DataFrame()

thema['thema1'] = thema1['Close']
thema['thema2'] = thema2['Close']
thema['thema3'] = thema3['Close']
thema['thema4'] = thema4['Close']
thema['thema5'] = thema5['Close']
thema['thema6'] = thema5['Close']
thema['thema7'] = thema5['Close']
#(1)에 추가했을 경우 이 부분도 추가해주세요


plt.figure(figsize=(12, 6))
plt.plot(thema.index, thema['thema1'], label='현대엘리베이터')
plt.plot(thema.index, thema['thema2'], label='한창')
plt.plot(thema.index, thema['thema3'], label='재영솔루텍')
plt.plot(thema.index, thema['thema4'], label='용현BM')
plt.plot(thema.index, thema['thema5'], label='현대상선')
plt.plot(thema.index, thema['thema6'], label='에머슨퍼시픽')
plt.plot(thema.index, thema['thema7'], label='신원')
#(1)에 추가했을 경우 이 부분도 추가해주세요

#경선 일에 빨간 점선 줄
plt.axvline(x=pd.to_datetime('2007-12-19'), color='red', linestyle='--', label='선거일') #경선일을 수정하려면 datatime변수 수정해주시면 됩니다.

plt.xlabel('날짜')
plt.ylabel('종가')
plt.title('정동영_테마주')
plt.legend()
plt.grid(True)
plt.show()
