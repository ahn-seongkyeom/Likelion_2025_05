# %%
import FinanceDataReader as fdr
import pandas as pd
import warnings
import yfinance as yf
import statsmodels.api as sm

warnings.filterwarnings('ignore')

start_date = '2012-09-06' # 경선확정일 - 10
end_date = '2012-09-26' # 경선확정일 + 10

label_dict = {
    'thema1': '우리들제약',
    'thema3': '에이엔피',
    'thema4': '피에스엠씨',
    'thema5': '바른손',
    'thema6': '유성티엔에스',
    'thema7': '서희건설',
    'thema9': '조광페인트',
}


code_dict = {
    'thema1': '004720.KS',
    'thema3': '015260.KS',
    'thema4': '024850.KS',
    'thema5': '018700.KS',
    'thema6': '024800.KS',
    'thema7': '035890.KS',
    'thema9': '004910.KS'
    
}

thema = pd.DataFrame()
for key, code in code_dict.items():
    df = yf.download(code, start=start_date, end=end_date, auto_adjust=False)
    thema[key] = df['Close']
    
kospi_df = fdr.DataReader('KS11', start=start_date, end=end_date)
kospi_ret = kospi_df['Close'].pct_change().dropna()

print(f"\n[Market Model 회귀분석 결과: {start_date} ~ {end_date}]")
print("종목명\t\tα\t\tβ\t\tR²")

for key in thema.columns:
    stock = thema[key]
    if stock.dropna().shape[0] < 3:
        print(f"{label_dict[key]:<8}\tN/A\t\tN/A\t\tN/A")
        continue

    stock_ret = stock.pct_change().dropna()

    aligned = pd.concat([stock_ret, kospi_ret], axis=1, join='inner').dropna()
    aligned.columns = ['stock_ret', 'kospi_ret']

    if len(aligned) < 3:
        print(f"{label_dict[key]:<8}\tN/A\t\tN/A\t\tN/A")
        continue

    X = sm.add_constant(aligned['kospi_ret'])
    y = aligned['stock_ret']
    model = sm.OLS(y, X).fit()

    alpha = round(model.params[0], 4)
    beta = round(model.params[1], 4)
    r2 = round(model.rsquared, 4)

    print(f"{label_dict[key]:<8}\t{alpha:<8}\t{beta:<8}\t{r2}")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [Market Model 회귀분석 결과: 2012-09-06 ~ 2012-09-26]
# 종목명		α		β		R²
# 우리들제약   	-0.0099 	-0.7467 	0.0058
# 에이엔피    	-0.0198 	0.0365  	0.0
# 피에스엠씨   	-0.0055 	1.0042  	0.0898
# 바른손     	-0.0077 	-0.0008 	0.0
# 유성티엔에스  	0.0015  	1.8869  	0.1955
# 서희건설    	0.0097  	2.1526  	0.0846
# 조광페인트   	-0.0023 	0.8115  	0.0163

# %%
import FinanceDataReader as fdr
import pandas as pd
import warnings
import yfinance as yf
import statsmodels.api as sm

warnings.filterwarnings('ignore')

start_date = '2012-11-09' # 선거일 - 40
end_date = '2013-01-28' # 선거일 + 40

label_dict = {
    'thema1': '우리들제약',
    'thema3': '에이엔피',
    'thema4': '피에스엠씨',
    'thema5': '바른손',
    'thema6': '유성티엔에스',
    'thema7': '서희건설',
    'thema9': '조광페인트',
}


code_dict = {
    'thema1': '004720.KS',
    'thema3': '015260.KS',
    'thema4': '024850.KS',
    'thema5': '018700.KS',
    'thema6': '024800.KS',
    'thema7': '035890.KS',
    'thema9': '004910.KS'
    
}

thema = pd.DataFrame()
for key, code in code_dict.items():
    df = yf.download(code, start=start_date, end=end_date, auto_adjust=False)
    thema[key] = df['Close']
    
kospi_df = fdr.DataReader('KS11', start=start_date, end=end_date)
kospi_ret = kospi_df['Close'].pct_change().dropna()

print(f"\n[Market Model 회귀분석 결과: {start_date} ~ {end_date}]")
print("종목명\t\tα\t\tβ\t\tR²")

for key in thema.columns:
    stock = thema[key]
    if stock.dropna().shape[0] < 3:
        print(f"{label_dict[key]:<8}\tN/A\t\tN/A\t\tN/A")
        continue

    stock_ret = stock.pct_change().dropna()

    aligned = pd.concat([stock_ret, kospi_ret], axis=1, join='inner').dropna()
    aligned.columns = ['stock_ret', 'kospi_ret']

    if len(aligned) < 3:
        print(f"{label_dict[key]:<8}\tN/A\t\tN/A\t\tN/A")
        continue

    X = sm.add_constant(aligned['kospi_ret'])
    y = aligned['stock_ret']
    model = sm.OLS(y, X).fit()

    alpha = round(model.params[0], 4)
    beta = round(model.params[1], 4)
    r2 = round(model.rsquared, 4)

    print(f"{label_dict[key]:<8}\t{alpha:<8}\t{beta:<8}\t{r2}")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [Market Model 회귀분석 결과: 2012-11-09 ~ 2013-01-28]
# 종목명		α		β		R²
# 우리들제약   	-0.016  	1.4108  	0.01
# 에이엔피    	-0.0042 	-1.355  	0.0221
# 피에스엠씨   	0.0059  	1.0919  	0.0477
# 바른손     	-0.0111 	2.0493  	0.0264
# 유성티엔에스  	-0.0039 	0.5755  	0.0043
# 서희건설    	-0.0027 	0.7441  	0.0119
# 조광페인트   	-0.0064 	-0.0123 	0.0
