# %%
import FinanceDataReader as fdr
import pandas as pd
import warnings
import yfinance as yf
import statsmodels.api as sm

warnings.filterwarnings('ignore')

start_date = '2025-04-23' #경선확정일 - 10
end_date = '2025-05-13' #경선확정일 + 10

label_dict = {
    'thema1': '평화산업',
    'thema2': '평화홀딩스',
    'thema3': '대영포장',
    'thema4': '한솔홈데코',
}


code_dict = {
    'thema1': '090080',
    'thema2': '010770',
    'thema3': '014160',
    'thema4': '025750' 
}

thema = pd.DataFrame()
for key, code in code_dict.items():
    df = fdr.DataReader(code, start=start_date, end=end_date)
    thema[key] = df['Close']
    
kospi_df = fdr.DataReader('KS11', start=start_date, end=end_date)
kospi_ret = kospi_df['Close'].pct_change().dropna()

print(f"\n[Market Model 회귀분석 결과: {start_date} ~ {end_date}]")
print("종목명\t\tα\t\tβ\t\tR²")

for key in thema.columns:
    stock = thema[key]
    if stock.dropna().shape[0] < 3:
        print(f"{label_dict[key]:<8}\tN/A\t\tN/A\t\tN/A")
        continue

    stock_ret = stock.pct_change().dropna()

    aligned = pd.concat([stock_ret, kospi_ret], axis=1, join='inner').dropna()
    aligned.columns = ['stock_ret', 'kospi_ret']

    if len(aligned) < 3:
        print(f"{label_dict[key]:<8}\tN/A\t\tN/A\t\tN/A")
        continue

    X = sm.add_constant(aligned['kospi_ret'])
    y = aligned['stock_ret']
    model = sm.OLS(y, X).fit()

    alpha = round(model.params[0], 4)
    beta = round(model.params[1], 4)
    r2 = round(model.rsquared, 4)

    print(f"{label_dict[key]:<8}\t{alpha:<8}\t{beta:<8}\t{r2}")
# Out:
# [Market Model 회귀분석 결과: 2025-04-23 ~ 2025-05-13]
# 종목명		α		β		R²
# 평화산업    	-0.0045 	12.8231 	0.2788
# 평화홀딩스   	0.021   	9.829   	0.0764
# 대영포장    	-0.0441 	15.1481 	0.4407
# 한솔홈데코   	-0.0385 	12.6847 	0.4298

# %%
import FinanceDataReader as fdr
import pandas as pd
import warnings
import yfinance as yf
import statsmodels.api as sm

warnings.filterwarnings('ignore')

start_date = '2025-04-23' #경선확정일 - 10
end_date = '2025-05-13' #경선확정일 + 10

label_dict = {
    'thema1': '평화산업',
    'thema2': '평화홀딩스',
    'thema3': '대영포장',
    'thema4': '한솔홈데코',
}


code_dict = {
    'thema1': '090080',
    'thema2': '010770',
    'thema3': '014160',
    'thema4': '025750' 
}

thema = pd.DataFrame()
for key, code in code_dict.items():
    df = fdr.DataReader(code, start=start_date, end=end_date)
    thema[key] = df['Close']
    
kospi_df = fdr.DataReader('KS11', start=start_date, end=end_date)
kospi_ret = kospi_df['Close'].pct_change().dropna()

print(f"\n[Market Model 회귀분석 결과: {start_date} ~ {end_date}]")
print("종목명\t\tα\t\tβ\t\tR²")

for key in thema.columns:
    stock = thema[key]
    if stock.dropna().shape[0] < 3:
        print(f"{label_dict[key]:<8}\tN/A\t\tN/A\t\tN/A")
        continue

    stock_ret = stock.pct_change().dropna()

    aligned = pd.concat([stock_ret, kospi_ret], axis=1, join='inner').dropna()
    aligned.columns = ['stock_ret', 'kospi_ret']

    if len(aligned) < 3:
        print(f"{label_dict[key]:<8}\tN/A\t\tN/A\t\tN/A")
        continue

    X = sm.add_constant(aligned['kospi_ret'])
    y = aligned['stock_ret']
    model = sm.OLS(y, X).fit()

    alpha = round(model.params[0], 4)
    beta = round(model.params[1], 4)
    r2 = round(model.rsquared, 4)

    print(f"{label_dict[key]:<8}\t{alpha:<8}\t{beta:<8}\t{r2}")
# Out:
# [Market Model 회귀분석 결과: 2025-04-23 ~ 2025-05-13]
# 종목명		α		β		R²
# 평화산업    	0.0025  	13.122  	0.2337
# 평화홀딩스   	0.0349  	7.1671  	0.0325
# 대영포장    	-0.0349 	15.1872 	0.3546
# 한솔홈데코   	-0.0334 	13.5979 	0.3953
