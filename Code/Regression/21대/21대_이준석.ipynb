# %%
import FinanceDataReader as fdr
import pandas as pd
import warnings
import yfinance as yf
import statsmodels.api as sm

warnings.filterwarnings('ignore')

start_date = '2025-03-29' #경선확정일 - 10
end_date = '2025-04-18' #경선확정일 + 10

label_dict = {
    'thema1': '삼보산업',
    'thema2': '넥스트아이',
    'thema3': 'YBM넷',
    'thema4': '태영건설',
    'thema5': '에쎈테크',
    'thema6': '비트컴퓨터',
    'thema7': '삼영',
    'thema8': '대성창투',
    'thema9': '비케이홀딩스',
    'thema10' : '윌비스'
}


code_dict = {
    'thema1': '009620',
    'thema2': '137940',
    'thema3': '057030',
    'thema4': '009410',
    'thema5': '043340',
    'thema6': '032850',
    'thema7': '003720',
    'thema8': '027830',
    'thema9': '050090',
    'thema10': '008600',
    
}

thema = pd.DataFrame()
for key, code in code_dict.items():
    df = fdr.DataReader(code, start=start_date, end=end_date)
    thema[key] = df['Close']
    
kospi_df = fdr.DataReader('KS11', start=start_date, end=end_date)
kospi_ret = kospi_df['Close'].pct_change().dropna()

print(f"\n[Market Model 회귀분석 결과: {start_date} ~ {end_date}]")
print("종목명\t\tα\t\tβ\t\tR²")

for key in thema.columns:
    stock = thema[key]
    if stock.dropna().shape[0] < 3:
        print(f"{label_dict[key]:<8}\tN/A\t\tN/A\t\tN/A")
        continue

    stock_ret = stock.pct_change().dropna()

    aligned = pd.concat([stock_ret, kospi_ret], axis=1, join='inner').dropna()
    aligned.columns = ['stock_ret', 'kospi_ret']

    if len(aligned) < 3:
        print(f"{label_dict[key]:<8}\tN/A\t\tN/A\t\tN/A")
        continue

    X = sm.add_constant(aligned['kospi_ret'])
    y = aligned['stock_ret']
    model = sm.OLS(y, X).fit()

    alpha = round(model.params[0], 4)
    beta = round(model.params[1], 4)
    r2 = round(model.rsquared, 4)

    print(f"{label_dict[key]:<8}\t{alpha:<8}\t{beta:<8}\t{r2}")
# Out:
# [Market Model 회귀분석 결과: 2025-03-29 ~ 2025-04-18]
# 종목명		α		β		R²
# 삼보산업    	0.0386  	0.6452  	0.0352
# 넥스트아이   	0.0466  	0.3182  	0.013
# YBM넷    	0.0192  	0.3676  	0.0464
# 태영건설    	-0.0015 	0.8081  	0.5444
# 에쎈테크    	0.0119  	-0.9836 	0.0803
# 비트컴퓨터   	0.014   	0.5459  	0.1809
# 삼영      	0.0046  	0.8265  	0.527
# 대성창투    	0.0354  	1.1606  	0.2055
# 비케이홀딩스  	0.0235  	2.6648  	0.3784
# 윌비스     	0.0448  	-1.0534 	0.0442

# %%
import FinanceDataReader as fdr
import pandas as pd
import warnings
import yfinance as yf
import statsmodels.api as sm

warnings.filterwarnings('ignore')

start_date = '2025-04-20' # 선거일 - 40
end_date = '2025-05-29' # 선거일 + 40


label_dict = {
    'thema1': '삼보산업',
    'thema2': '넥스트아이',
    'thema3': 'YBM넷',
    'thema4': '태영건설',
    'thema5': '에쎈테크',
    'thema6': '비트컴퓨터',
    'thema7': '삼영',
    'thema8': '대성창투',
    'thema9': '비케이홀딩스',
    'thema10' : '윌비스'
}


code_dict = {
    'thema1': '009620',
    'thema2': '137940',
    'thema3': '057030',
    'thema4': '009410',
    'thema5': '043340',
    'thema6': '032850',
    'thema7': '003720',
    'thema8': '027830',
    'thema9': '050090',
    'thema10': '008600',
    
}

thema = pd.DataFrame()
for key, code in code_dict.items():
    df = fdr.DataReader(code, start=start_date, end=end_date)
    thema[key] = df['Close']
    
kospi_df = fdr.DataReader('KS11', start=start_date, end=end_date)
kospi_ret = kospi_df['Close'].pct_change().dropna()

print(f"\n[Market Model 회귀분석 결과: {start_date} ~ {end_date}]")
print("종목명\t\tα\t\tβ\t\tR²")

for key in thema.columns:
    stock = thema[key]
    if stock.dropna().shape[0] < 3:
        print(f"{label_dict[key]:<8}\tN/A\t\tN/A\t\tN/A")
        continue

    stock_ret = stock.pct_change().dropna()

    aligned = pd.concat([stock_ret, kospi_ret], axis=1, join='inner').dropna()
    aligned.columns = ['stock_ret', 'kospi_ret']

    if len(aligned) < 3:
        print(f"{label_dict[key]:<8}\tN/A\t\tN/A\t\tN/A")
        continue

    X = sm.add_constant(aligned['kospi_ret'])
    y = aligned['stock_ret']
    model = sm.OLS(y, X).fit()

    alpha = round(model.params[0], 4)
    beta = round(model.params[1], 4)
    r2 = round(model.rsquared, 4)

    print(f"{label_dict[key]:<8}\t{alpha:<8}\t{beta:<8}\t{r2}")
# Out:
# [Market Model 회귀분석 결과: 2025-04-20 ~ 2025-05-29]
# 종목명		α		β		R²
# 삼보산업    	-0.0225 	0.7838  	0.004
# 넥스트아이   	-0.0122 	0.1017  	0.0001
# YBM넷    	-0.0117 	1.3178  	0.0259
# 태영건설    	0.0038  	1.0161  	0.018
# 에쎈테크    	-0.0057 	0.2611  	0.0067
# 비트컴퓨터   	-0.0023 	0.2403  	0.0137
# 삼영      	-0.0037 	1.2254  	0.2067
# 대성창투    	-0.0143 	0.0973  	0.0002
# 비케이홀딩스  	0.009   	-0.8411 	0.009
# 윌비스     	-0.0275 	2.5432  	0.0507
