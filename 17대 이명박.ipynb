# %%
import FinanceDataReader as fdr
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings
import matplotlib as mpl
warnings.filterwarnings('ignore')ㅡ
mpl.rc('font', family='Malgun Gothic')  
mpl.rcParams['axes.unicode_minus'] = False

start_date = '2007-08-09' #경선확정일 - 10
end_date = '2007-08-29' #경선확정일 + 10

thema1 = fdr.DataReader('000720', start=start_date, end=end_date) #테마주1
thema2 = fdr.DataReader('025100', start=start_date, end=end_date)
thema3 = fdr.DataReader('034020', start=start_date, end=end_date)
thema4 = fdr.DataReader('026150', start=start_date, end=end_date)
thema5 = fdr.DataReader('010960', start=start_date, end=end_date)
thema6 = fdr.DataReader('014790', start=start_date, end=end_date)
thema7 = fdr.DataReader('001840', start=start_date, end=end_date)
thema8 = fdr.DataReader('004980', start=start_date, end=end_date)
thema9 = fdr.DataReader('047040', start=start_date, end=end_date)#테마주2  테마를 추가하고싶으면 아래에 이어서 적으시면됩니다.# thema2 = fdr.DataReader('015260', start=start_date, end=end_date) 
#(1) 이 밑으로 계속 추가한 후 plt 부분에 같이 추가하시면 같이 시각화 가능

thema= pd.DataFrame()

thema['thema1'] = thema1['Close']
thema['thema2'] = thema2['Close']
thema['thema3'] = thema3['Close']
thema['thema4'] = thema4['Close']
thema['thema5'] = thema5['Close']
thema['thema6'] = thema5['Close']
thema['thema7'] = thema5['Close']
thema['thema8'] = thema5['Close']
thema['thema9'] = thema5['Close']
#(1)에 추가했을 경우 이 부분도 추가해주세요


plt.figure(figsize=(12, 6))
plt.plot(thema.index, thema['thema1'], label='현대건설')
plt.plot(thema.index, thema['thema2'], label='포스코건설')
plt.plot(thema.index, thema['thema3'], label='두산중공업')
plt.plot(thema.index, thema['thema4'], label='특수건설')
plt.plot(thema.index, thema['thema5'], label='삼호개발')
plt.plot(thema.index, thema['thema5'], label='한라건설')
plt.plot(thema.index, thema['thema5'], label='이화공영')
plt.plot(thema.index, thema['thema5'], label='성신양회')
plt.plot(thema.index, thema['thema5'], label='대우건설')
#(1)에 추가했을 경우 이 부분도 추가해주세요

#경선 일에 빨간 점선 줄
plt.axvline(x=pd.to_datetime('2007-08-19'), color='red', linestyle='--', label='경선일') #경선일을 수정하려면 datatime변수 수정해주시면 됩니다.

plt.xlabel('날짜')
plt.ylabel('종가')
plt.title('이명박_테마주')
plt.legend()
plt.grid(True)
plt.show()

# %%
import FinanceDataReader as fdr
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings
import matplotlib as mpl
warnings.filterwarnings('ignore')ㅡ
mpl.rc('font', family='Malgun Gothic')  
mpl.rcParams['axes.unicode_minus'] = False

start_date = '2007-11-09' #경선확정일 - 40
end_date = '2008-01-28' #경선확정일 + 40

thema1 = fdr.DataReader('000720', start=start_date, end=end_date) #테마주1
thema2 = fdr.DataReader('025100', start=start_date, end=end_date)
thema3 = fdr.DataReader('034020', start=start_date, end=end_date)
thema4 = fdr.DataReader('026150', start=start_date, end=end_date)
thema5 = fdr.DataReader('010960', start=start_date, end=end_date)
thema6 = fdr.DataReader('014790', start=start_date, end=end_date)
thema7 = fdr.DataReader('001840', start=start_date, end=end_date)
thema8 = fdr.DataReader('004980', start=start_date, end=end_date)
thema9 = fdr.DataReader('047040', start=start_date, end=end_date)#테마주2  테마를 추가하고싶으면 아래에 이어서 적으시면됩니다.# thema2 = fdr.DataReader('015260', start=start_date, end=end_date) 
#(1) 이 밑으로 계속 추가한 후 plt 부분에 같이 추가하시면 같이 시각화 가능

thema= pd.DataFrame()

thema['thema1'] = thema1['Close']
thema['thema2'] = thema2['Close']
thema['thema3'] = thema3['Close']
thema['thema4'] = thema4['Close']
thema['thema5'] = thema5['Close']
thema['thema6'] = thema5['Close']
thema['thema7'] = thema5['Close']
thema['thema8'] = thema5['Close']
thema['thema9'] = thema5['Close']
#(1)에 추가했을 경우 이 부분도 추가해주세요


plt.figure(figsize=(12, 6))
plt.plot(thema.index, thema['thema1'], label='현대건설')
plt.plot(thema.index, thema['thema2'], label='포스코건설')
plt.plot(thema.index, thema['thema3'], label='두산중공업')
plt.plot(thema.index, thema['thema4'], label='특수건설')
plt.plot(thema.index, thema['thema5'], label='삼호개발')
plt.plot(thema.index, thema['thema5'], label='한라건설')
plt.plot(thema.index, thema['thema5'], label='이화공영')
plt.plot(thema.index, thema['thema5'], label='성신양회')
plt.plot(thema.index, thema['thema5'], label='대우건설')
#(1)에 추가했을 경우 이 부분도 추가해주세요

#경선 일에 빨간 점선 줄
plt.axvline(x=pd.to_datetime('2007-12-19'), color='red', linestyle='--', label='선거일') #선거일을 수정하려면 datatime변수 수정해주시면 됩니다.

plt.xlabel('날짜')
plt.ylabel('종가')
plt.title('이명박_테마주')
plt.legend()
plt.grid(True)
plt.show()
