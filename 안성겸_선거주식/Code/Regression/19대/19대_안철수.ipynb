# %%
import FinanceDataReader as fdr
import pandas as pd
import warnings
import yfinance as yf
import statsmodels.api as sm

warnings.filterwarnings('ignore')

start_date = '2017-03-24' #경선확정일 - 10
end_date = '2017-04-13' #경선확정일 + 10

label_dict = {
    'thema1': '써니전자',
    'thema2': '콤텍시스템',
    'thema3': '우성사료',
    'thema4': '솔고바이오메디칼',
    'thema5': '한국정보공학',
    'thema6': '미래산업',
    'thema7': '휴맥스',
    'thema8': '다믈멀티미디어',
    'thema9': '브리지텍',
    'thema10': '아남전자'
}


code_dict = {
    'thema1': '004770',
    'thema2': '031820',
    'thema3': '006980',
    'thema4': '043100',
    'thema5': '039740',
    'thema6': '025560',
    'thema7': '115160',
    'thema8': '093640',
    'thema9': '064480',
    'thema10': '008700'  
}

thema = pd.DataFrame()
for key, code in code_dict.items():
    df = fdr.DataReader(code, start=start_date, end=end_date)
    thema[key] = df['Close']
    
kospi_df = fdr.DataReader('KS11', start=start_date, end=end_date)
kospi_ret = kospi_df['Close'].pct_change().dropna()

print(f"\n[Market Model 회귀분석 결과: {start_date} ~ {end_date}]")
print("종목명\t\tα\t\tβ\t\tR²")

for key in thema.columns:
    stock = thema[key]
    if stock.dropna().shape[0] < 3:
        print(f"{label_dict[key]:<8}\tN/A\t\tN/A\t\tN/A")
        continue

    stock_ret = stock.pct_change().dropna()

    aligned = pd.concat([stock_ret, kospi_ret], axis=1, join='inner').dropna()
    aligned.columns = ['stock_ret', 'kospi_ret']

    if len(aligned) < 3:
        print(f"{label_dict[key]:<8}\tN/A\t\tN/A\t\tN/A")
        continue

    X = sm.add_constant(aligned['kospi_ret'])
    y = aligned['stock_ret']
    model = sm.OLS(y, X).fit()

    alpha = round(model.params[0], 4)
    beta = round(model.params[1], 4)
    r2 = round(model.rsquared, 4)

    print(f"{label_dict[key]:<8}\t{alpha:<8}\t{beta:<8}\t{r2}")
# Out:
# [Market Model 회귀분석 결과: 2017-03-24 ~ 2017-04-13]
# 종목명		α		β		R²
# 써니전자    	0.0235  	-5.2171 	0.0329
# 콤텍시스템   	0.0082  	2.0479  	0.0483
# 우성사료    	0.0018  	-2.6464 	0.0111
# 솔고바이오메디칼	0.0018  	1.4306  	0.1233
# 한국정보공학  	-0.002  	1.5875  	0.0344
# 미래산업    	0.0152  	3.4513  	0.0199
# 휴맥스     	-0.0013 	0.7699  	0.1746
# 다믈멀티미디어 	-0.0042 	-3.3057 	0.0193
# 브리지텍    	0.0149  	-1.6329 	0.0222
# 아남전자    	0.0086  	3.5462  	0.0129

# %%
import FinanceDataReader as fdr
import pandas as pd
import warnings
import yfinance as yf
import statsmodels.api as sm

warnings.filterwarnings('ignore')

start_date = '2017-03-30' #선거날 - 40
end_date = '2017-06-17' # 선거날 +40


label_dict = {
    'thema1': '써니전자',
    'thema2': '콤텍시스템',
    'thema3': '우성사료',
    'thema4': '솔고바이오메디칼',
    'thema5': '한국정보공학',
    'thema6': '미래산업',
    'thema7': '휴맥스',
    'thema8': '다믈멀티미디어',
    'thema9': '브리지텍',
    'thema10': '아남전자'
}


code_dict = {
    'thema1': '004770',
    'thema2': '031820',
    'thema3': '006980',
    'thema4': '043100',
    'thema5': '039740',
    'thema6': '025560',
    'thema7': '115160',
    'thema8': '093640',
    'thema9': '064480',
    'thema10': '008700'  
}

thema = pd.DataFrame()
for key, code in code_dict.items():
    df = fdr.DataReader(code, start=start_date, end=end_date)
    thema[key] = df['Close']
    
kospi_df = fdr.DataReader('KS11', start=start_date, end=end_date)
kospi_ret = kospi_df['Close'].pct_change().dropna()

print(f"\n[Market Model 회귀분석 결과: {start_date} ~ {end_date}]")
print("종목명\t\tα\t\tβ\t\tR²")

for key in thema.columns:
    stock = thema[key]
    if stock.dropna().shape[0] < 3:
        print(f"{label_dict[key]:<8}\tN/A\t\tN/A\t\tN/A")
        continue

    stock_ret = stock.pct_change().dropna()

    aligned = pd.concat([stock_ret, kospi_ret], axis=1, join='inner').dropna()
    aligned.columns = ['stock_ret', 'kospi_ret']

    if len(aligned) < 3:
        print(f"{label_dict[key]:<8}\tN/A\t\tN/A\t\tN/A")
        continue

    X = sm.add_constant(aligned['kospi_ret'])
    y = aligned['stock_ret']
    model = sm.OLS(y, X).fit()

    alpha = round(model.params[0], 4)
    beta = round(model.params[1], 4)
    r2 = round(model.rsquared, 4)

    print(f"{label_dict[key]:<8}\t{alpha:<8}\t{beta:<8}\t{r2}")
# Out:
# [Market Model 회귀분석 결과: 2017-03-30 ~ 2017-06-17]
# 종목명		α		β		R²
# 써니전자    	-0.0144 	-1.1682 	0.0112
# 콤텍시스템   	-0.0048 	1.1176  	0.0828
# 우성사료    	-0.0137 	0.8486  	0.0165
# 솔고바이오메디칼	-0.0032 	0.7613  	0.1638
# 한국정보공학  	-0.0073 	0.1644  	0.0014
# 미래산업    	-0.0078 	0.5751  	0.0085
# 휴맥스     	-0.0006 	0.1403  	0.0078
# 다믈멀티미디어 	-0.0138 	0.2711  	0.001
# 브리지텍    	0.0011  	-0.2288 	0.002
# 아남전자    	-0.0004 	-1.0461 	0.0054
