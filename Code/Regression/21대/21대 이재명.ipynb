# %%
import FinanceDataReader as fdr
import pandas as pd
import warnings
import yfinance as yf
import statsmodels.api as sm

warnings.filterwarnings('ignore')

start_date = '2025-04-17' #경선확정일 - 10
end_date = '2025-05-07' #경선확정일 + 10

label_dict = {
    'thema1': '일성건설',
    'thema2': '형지엘리트',
    'thema3': '코나아이',
    'thema4': '에이텍모빌리티',
    'thema5': '슈프리마에이치큐',
    'thema6': '카스',
    'thema7': '지엘팜텍',
    'thema8': '앱트뉴로사이언스',
    'thema9': '이스타코',
    'thema10' : '코이즈'
}


code_dict = {
    'thema1': '013360',
    'thema2': '093240',
    'thema3': '052400',
    'thema4': '024110',
    'thema5': '094840',
    'thema6': '016920',
    'thema7': '204840',
    'thema8': '217330',
    'thema9': '015020',
    'thema10': '121850',
}

thema = pd.DataFrame()
for key, code in code_dict.items():
    df = fdr.DataReader(code, start=start_date, end=end_date)
    thema[key] = df['Close']
    
kospi_df = fdr.DataReader('KS11', start=start_date, end=end_date)
kospi_ret = kospi_df['Close'].pct_change().dropna()

print(f"\n[Market Model 회귀분석 결과: {start_date} ~ {end_date}]")
print("종목명\t\tα\t\tβ\t\tR²")

for key in thema.columns:
    stock = thema[key]
    if stock.dropna().shape[0] < 3:
        print(f"{label_dict[key]:<8}\tN/A\t\tN/A\t\tN/A")
        continue

    stock_ret = stock.pct_change().dropna()

    aligned = pd.concat([stock_ret, kospi_ret], axis=1, join='inner').dropna()
    aligned.columns = ['stock_ret', 'kospi_ret']

    if len(aligned) < 3:
        print(f"{label_dict[key]:<8}\tN/A\t\tN/A\t\tN/A")
        continue

    X = sm.add_constant(aligned['kospi_ret'])
    y = aligned['stock_ret']
    model = sm.OLS(y, X).fit()

    alpha = round(model.params[0], 4)
    beta = round(model.params[1], 4)
    r2 = round(model.rsquared, 4)

    print(f"{label_dict[key]:<8}\t{alpha:<8}\t{beta:<8}\t{r2}")
# Out:
# [Market Model 회귀분석 결과: 2025-04-17 ~ 2025-05-07]
# 종목명		α		β		R²
# 일성건설    	-0.0024 	0.4491  	0.0009
# 형지엘리트   	0.0238  	-5.3712 	0.0722
# 코나아이    	0.0451  	-2.1422 	0.0133
# 에이텍모빌리티 	0.0052  	-0.0275 	0.0005
# 슈프리마에이치큐	-0.0006 	4.1762  	0.0491
# 카스      	-0.0046 	0.1545  	0.0003
# 지엘팜텍    	-0.0114 	10.9234 	0.3685
# 앱트뉴로사이언스	0.0173  	-2.9075 	0.0569
# 이스타코    	0.0135  	-2.0442 	0.011
# 코이즈     	-0.0046 	-0.2393 	0.0007

# %%
import FinanceDataReader as fdr
import pandas as pd
import warnings
import yfinance as yf
import statsmodels.api as sm

warnings.filterwarnings('ignore')

start_date = '2025-04-20' # 선거일 - 40
end_date = '2025-05-29' # 선거일 + 40


label_dict = {
    'thema1': '일성건설',
    'thema2': '형지엘리트',
    'thema3': '코나아이',
    'thema4': '에이텍모빌리티',
    'thema5': '슈프리마에이치큐',
    'thema6': '카스',
    'thema7': '지엘팜텍',
    'thema8': '앱트뉴로사이언스',
    'thema9': '이스타코',
    'thema10' : '코이즈'
}


code_dict = {
    'thema1': '013360',
    'thema2': '093240',
    'thema3': '052400',
    'thema4': '024110',
    'thema5': '094840',
    'thema6': '016920',
    'thema7': '204840',
    'thema8': '217330',
    'thema9': '015020',
    'thema10': '121850',
}

thema = pd.DataFrame()
for key, code in code_dict.items():
    df = fdr.DataReader(code, start=start_date, end=end_date)
    thema[key] = df['Close']
    
kospi_df = fdr.DataReader('KS11', start=start_date, end=end_date)
kospi_ret = kospi_df['Close'].pct_change().dropna()

print(f"\n[Market Model 회귀분석 결과: {start_date} ~ {end_date}]")
print("종목명\t\tα\t\tβ\t\tR²")

for key in thema.columns:
    stock = thema[key]
    if stock.dropna().shape[0] < 3:
        print(f"{label_dict[key]:<8}\tN/A\t\tN/A\t\tN/A")
        continue

    stock_ret = stock.pct_change().dropna()

    aligned = pd.concat([stock_ret, kospi_ret], axis=1, join='inner').dropna()
    aligned.columns = ['stock_ret', 'kospi_ret']

    if len(aligned) < 3:
        print(f"{label_dict[key]:<8}\tN/A\t\tN/A\t\tN/A")
        continue

    X = sm.add_constant(aligned['kospi_ret'])
    y = aligned['stock_ret']
    model = sm.OLS(y, X).fit()

    alpha = round(model.params[0], 4)
    beta = round(model.params[1], 4)
    r2 = round(model.rsquared, 4)

    print(f"{label_dict[key]:<8}\t{alpha:<8}\t{beta:<8}\t{r2}")
# Out:
# [Market Model 회귀분석 결과: 2025-04-20 ~ 2025-05-29]
# 종목명		α		β		R²
# 일성건설    	-0.0163 	0.9913  	0.0181
# 형지엘리트   	-0.0108 	0.2568  	0.0007
# 코나아이    	0.0045  	1.6612  	0.0329
# 에이텍모빌리티 	0.0012  	0.3521  	0.1721
# 슈프리마에이치큐	-0.0037 	2.1841  	0.0692
# 카스      	-0.0138 	0.8278  	0.0396
# 지엘팜텍    	0.0031  	2.1011  	0.0696
# 앱트뉴로사이언스	0.0101  	-2.3208 	0.0549
# 이스타코    	-0.0167 	1.0623  	0.0108
# 코이즈     	-0.0146 	1.1679  	0.0695
