# %%
import FinanceDataReader as fdr
import pandas as pd
import warnings
import yfinance as yf
import statsmodels.api as sm

warnings.filterwarnings('ignore')

start_date = '2012-08-10' #경선확정일 - 10
end_date = '2012-08-30' #경선확정일 + 10

label_dict = {
    'thema1': 'EG',
    'thema2': '동양물산',
    'thema3': '대유에이텍',
    'thema4': '대유신소재',
    'thema5' : '아가방컴퍼니',
    'thema6' : '보령메디앙스',
    'thema7' : '세운메디칼'
}


code_dict = {
    'thema1': '037370.KS',
    'thema2': '002900.KS',
    'thema3': '002880.KS',
    'thema4': '005930.KS',
    'thema5': '013990.KS',
    'thema6': '014100.KS',
    'thema7': '100700.KS'
    
}

thema = pd.DataFrame()
for key, code in code_dict.items():
    df = yf.download(code, start=start_date, end=end_date, auto_adjust=False)
    thema[key] = df['Close']
    
kospi_df = fdr.DataReader('KS11', start=start_date, end=end_date)
kospi_ret = kospi_df['Close'].pct_change().dropna()

print(f"\n[Market Model 회귀분석 결과: {start_date} ~ {end_date}]")
print("종목명\t\tα\t\tβ\t\tR²")

for key in thema.columns:
    stock = thema[key]
    if stock.dropna().shape[0] < 3:
        print(f"{label_dict[key]:<8}\tN/A\t\tN/A\t\tN/A")
        continue

    stock_ret = stock.pct_change().dropna()

    aligned = pd.concat([stock_ret, kospi_ret], axis=1, join='inner').dropna()
    aligned.columns = ['stock_ret', 'kospi_ret']

    if len(aligned) < 3:
        print(f"{label_dict[key]:<8}\tN/A\t\tN/A\t\tN/A")
        continue

    X = sm.add_constant(aligned['kospi_ret'])
    y = aligned['stock_ret']
    model = sm.OLS(y, X).fit()

    alpha = round(model.params[0], 4)
    beta = round(model.params[1], 4)
    r2 = round(model.rsquared, 4)

    print(f"{label_dict[key]:<8}\t{alpha:<8}\t{beta:<8}\t{r2}")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [Market Model 회귀분석 결과: 2012-08-10 ~ 2012-08-30]
# 종목명		α		β		R²
# EG      	0.0004  	-0.2621 	0.0045
# 동양물산    	0.0051  	-0.2311 	0.0034
# 대유에이텍   	0.0025  	-0.1953 	0.0061
# 대유신소재   	-0.0057 	2.1087  	0.2357
# 아가방컴퍼니  	0.0043  	0.19    	0.0035
# 보령메디앙스  	0.0039  	-0.4336 	0.02
# 세운메디칼   	0.0091  	1.1452  	0.131

# %%
import FinanceDataReader as fdr
import pandas as pd
import warnings
import yfinance as yf
import statsmodels.api as sm

warnings.filterwarnings('ignore')

start_date = '2012-11-09' # 선거일 - 40
end_date = '2013-01-28' # 선거일 + 40


label_dict = {
    'thema1': 'EG',
    'thema2': '동양물산',
    'thema3': '대유에이텍',
    'thema4': '대유신소재',
    'thema5' : '아가방컴퍼니',
    'thema6' : '보령메디앙스',
    'thema7' : '세운메디칼'
}


code_dict = {
    'thema1': '037370.KS',
    'thema2': '002900.KS',
    'thema3': '002880.KS',
    'thema4': '005930.KS',
    'thema5': '013990.KS',
    'thema6': '014100.KS',
    'thema7': '100700.KS'
    
}

thema = pd.DataFrame()
for key, code in code_dict.items():
    df = yf.download(code, start=start_date, end=end_date, auto_adjust=False)
    thema[key] = df['Close']
    
kospi_df = fdr.DataReader('KS11', start=start_date, end=end_date)
kospi_ret = kospi_df['Close'].pct_change().dropna()

print(f"\n[Market Model 회귀분석 결과: {start_date} ~ {end_date}]")
print("종목명\t\tα\t\tβ\t\tR²")

for key in thema.columns:
    stock = thema[key]
    if stock.dropna().shape[0] < 3:
        print(f"{label_dict[key]:<8}\tN/A\t\tN/A\t\tN/A")
        continue

    stock_ret = stock.pct_change().dropna()

    aligned = pd.concat([stock_ret, kospi_ret], axis=1, join='inner').dropna()
    aligned.columns = ['stock_ret', 'kospi_ret']

    if len(aligned) < 3:
        print(f"{label_dict[key]:<8}\tN/A\t\tN/A\t\tN/A")
        continue

    X = sm.add_constant(aligned['kospi_ret'])
    y = aligned['stock_ret']
    model = sm.OLS(y, X).fit()

    alpha = round(model.params[0], 4)
    beta = round(model.params[1], 4)
    r2 = round(model.rsquared, 4)

    print(f"{label_dict[key]:<8}\t{alpha:<8}\t{beta:<8}\t{r2}")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [Market Model 회귀분석 결과: 2012-11-09 ~ 2013-01-28]
# 종목명		α		β		R²
# EG      	0.0003  	1.4766  	0.0233
# 동양물산    	-0.0042 	1.4005  	0.0284
# 대유에이텍   	-0.0018 	0.8557  	0.0162
# 대유신소재   	0.0003  	1.9527  	0.6145
# 아가방컴퍼니  	-0.001  	1.2979  	0.0187
# 보령메디앙스  	0.0017  	1.4543  	0.0194
# 세운메디칼   	-0.003  	0.8281  	0.0354
