# %%
import FinanceDataReader as fdr
import pandas as pd
import warnings
import yfinance as yf
import statsmodels.api as sm

warnings.filterwarnings('ignore')

start_date = '2017-03-24' #경선확정일 - 10
end_date = '2017-04-13' #경선확정일 + 10

label_dict = {
    'thema1': '바른손',
    'thema2': '에이엔피',
    'thema3': '디오',
    'thema4': '국보디자인',
    'thema5': '신일산업',
    'thema6': '우리들제약',
    'thema7': '화인베스틸',
    'thema8': '대한제강',
    'thema9': '조광페인트',
    'thema10' : '유성티엔에스'
}



code_dict = {
    'thema1': '018700',
    'thema2': '015260',
    'thema3': '039840',
    'thema4': '066620',
    'thema5': '002700',
    'thema6': '004720',
    'thema7': '133820',
    'thema8': '084010',
    'thema9': '004910',
    'thema10': '024800'  
}

thema = pd.DataFrame()
for key, code in code_dict.items():
    df = fdr.DataReader(code, start=start_date, end=end_date)
    thema[key] = df['Close']
    
kospi_df = fdr.DataReader('KS11', start=start_date, end=end_date)
kospi_ret = kospi_df['Close'].pct_change().dropna()

print(f"\n[Market Model 회귀분석 결과: {start_date} ~ {end_date}]")
print("종목명\t\tα\t\tβ\t\tR²")

for key in thema.columns:
    stock = thema[key]
    if stock.dropna().shape[0] < 3:
        print(f"{label_dict[key]:<8}\tN/A\t\tN/A\t\tN/A")
        continue

    stock_ret = stock.pct_change().dropna()

    aligned = pd.concat([stock_ret, kospi_ret], axis=1, join='inner').dropna()
    aligned.columns = ['stock_ret', 'kospi_ret']

    if len(aligned) < 3:
        print(f"{label_dict[key]:<8}\tN/A\t\tN/A\t\tN/A")
        continue

    X = sm.add_constant(aligned['kospi_ret'])
    y = aligned['stock_ret']
    model = sm.OLS(y, X).fit()

    alpha = round(model.params[0], 4)
    beta = round(model.params[1], 4)
    r2 = round(model.rsquared, 4)

    print(f"{label_dict[key]:<8}\t{alpha:<8}\t{beta:<8}\t{r2}")
# Out:
# [Market Model 회귀분석 결과: 2017-03-24 ~ 2017-04-13]
# 종목명		α		β		R²
# 바른손     	-0.0276 	-1.5862 	0.0051
# 에이엔피    	-0.0173 	4.1616  	0.0973
# 디오      	0.0131  	-0.0697 	0.0001
# 국보디자인   	-0.0022 	0.7487  	0.0608
# 신일산업    	0.0058  	2.4199  	0.1082
# 우리들제약   	-0.0009 	3.3663  	0.0177
# 화인베스틸   	-0.0065 	1.8827  	0.0817
# 대한제강    	-0.0033 	0.721   	0.0192
# 조광페인트   	0.0017  	1.3016  	0.118
# 유성티엔에스  	-0.0091 	2.58    	0.0617

# %%
import FinanceDataReader as fdr
import pandas as pd
import warnings
import yfinance as yf
import statsmodels.api as sm

warnings.filterwarnings('ignore')

start_date = '2017-03-30' #선거날 - 40
end_date = '2017-06-17' # 선거날 +40

label_dict = {
    'thema1': '바른손',
    'thema2': '에이엔피',
    'thema3': '디오',
    'thema4': '국보디자인',
    'thema5': '신일산업',
    'thema6': '우리들제약',
    'thema7': '화인베스틸',
    'thema8': '대한제강',
    'thema9': '조광페인트',
    'thema10' : '유성티엔에스'
}



code_dict = {
    'thema1': '018700',
    'thema2': '015260',
    'thema3': '039840',
    'thema4': '066620',
    'thema5': '002700',
    'thema6': '004720',
    'thema7': '133820',
    'thema8': '084010',
    'thema9': '004910',
    'thema10': '024800'  
}

thema = pd.DataFrame()
for key, code in code_dict.items():
    df = fdr.DataReader(code, start=start_date, end=end_date)
    thema[key] = df['Close']
    
kospi_df = fdr.DataReader('KS11', start=start_date, end=end_date)
kospi_ret = kospi_df['Close'].pct_change().dropna()

print(f"\n[Market Model 회귀분석 결과: {start_date} ~ {end_date}]")
print("종목명\t\tα\t\tβ\t\tR²")

for key in thema.columns:
    stock = thema[key]
    if stock.dropna().shape[0] < 3:
        print(f"{label_dict[key]:<8}\tN/A\t\tN/A\t\tN/A")
        continue

    stock_ret = stock.pct_change().dropna()

    aligned = pd.concat([stock_ret, kospi_ret], axis=1, join='inner').dropna()
    aligned.columns = ['stock_ret', 'kospi_ret']

    if len(aligned) < 3:
        print(f"{label_dict[key]:<8}\tN/A\t\tN/A\t\tN/A")
        continue

    X = sm.add_constant(aligned['kospi_ret'])
    y = aligned['stock_ret']
    model = sm.OLS(y, X).fit()

    alpha = round(model.params[0], 4)
    beta = round(model.params[1], 4)
    r2 = round(model.rsquared, 4)

    print(f"{label_dict[key]:<8}\t{alpha:<8}\t{beta:<8}\t{r2}")
# Out:
# [Market Model 회귀분석 결과: 2017-03-30 ~ 2017-06-17]
# 종목명		α		β		R²
# 바른손     	-0.0204 	1.4573  	0.0163
# 에이엔피    	-0.0139 	1.874   	0.106
# 디오      	0.0028  	0.4183  	0.0094
# 국보디자인   	0.0017  	0.59    	0.0325
# 신일산업    	-0.0012 	0.111   	0.0014
# 우리들제약   	-0.023  	2.5627  	0.0529
# 화인베스틸   	-0.0039 	0.8164  	0.0705
# 대한제강    	0.0012  	0.197   	0.0041
# 조광페인트   	-0.0032 	0.7425  	0.1481
# 유성티엔에스  	-0.0077 	0.8922  	0.0396
